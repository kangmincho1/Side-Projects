# %% [markdown]
# # Clustering
# ## 성적 군집화

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
df = pd.read_csv(r'D:\git_space\data\grade.csv')
df
# Out:
#            name  midterm  final  attendance  attitude  homework
# 0       Ronaldo       90     94          10         8         8
# 1           Son       85     90          10         9         8
# 2         Messi       98     97          10         9        10
# 3        Dybala       75     70           8         8         9
# 4     Griezmann       70     65           8         7         7
# 5       Benzema       82     90           8         7         7
# 6        Neymar       95     91           7         5         8
# 7        Mbappe       90     97           9         9         9
# 8        Sancho       64     70           7         8         9
# 9         Pogba       59     45           4         5         6
# 10  Ibrahimovic       60     70           9         9         9
# 11         Ozil       31     56           4         7         7
# 12       Werner       80     85           9        10         9
# 13        Kroos       70     75          10        10        10
# 14      Kimmich       89     91          10        10        10
# 15      De Jong       87     61           7         9         8
# 16         Mane       89     87           9         7         7
# 17  Lewandowski       94     91           9         9        10
# 18         Park       65     31           4         9         7
# 19         Alli       36     45           4         5         6
# 20    De Bruyne       89     96           8         8         9
# 21      Mertens       75     70           7         7         7
# 22      Harzard       56     64           6         6         5
# 23        Kante       51     56           6         8         9
# 24      Insigne       67     72           8         8         7
# 25       Lukaku       23     34           8         7         8
# 26      Eriksen       21     14           2         5         8
# 27        Silva       87     64           9        10         9
# 28       Suarez       45     72           8         7         7
# 29      Lingard       34     45           8         2         7
# 30        Ramos       78     89          10         7         9

# %%
df.isnull().sum()
# Out:
# name          0
# midterm       0
# final         0
# attendance    0
# attitude      0
# homework      0
# dtype: int64

# %% [markdown]
# ## PCA

# %%
df.drop('name', axis=1, inplace=True)
df
# Out:
#     midterm  final  attendance  attitude  homework
# 0        90     94          10         8         8
# 1        85     90          10         9         8
# 2        98     97          10         9        10
# 3        75     70           8         8         9
# 4        70     65           8         7         7
# 5        82     90           8         7         7
# 6        95     91           7         5         8
# 7        90     97           9         9         9
# 8        64     70           7         8         9
# 9        59     45           4         5         6
# 10       60     70           9         9         9
# 11       31     56           4         7         7
# 12       80     85           9        10         9
# 13       70     75          10        10        10
# 14       89     91          10        10        10
# 15       87     61           7         9         8
# 16       89     87           9         7         7
# 17       94     91           9         9        10
# 18       65     31           4         9         7
# 19       36     45           4         5         6
# 20       89     96           8         8         9
# 21       75     70           7         7         7
# 22       56     64           6         6         5
# 23       51     56           6         8         9
# 24       67     72           8         8         7
# 25       23     34           8         7         8
# 26       21     14           2         5         8
# 27       87     64           9        10         9
# 28       45     72           8         7         7
# 29       34     45           8         2         7
# 30       78     89          10         7         9

# %%
features = df

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import MeanShift

# %%
meanshift = MeanShift(bandwidth=18) # bandwidth를 16으로 설정해보니 cluster가 다섯 개 형성된다
cluster_labels = meanshift.fit_predict(features)
print(np.unique(cluster_labels))
# Out:
# [0 1 2 3 4]

# %%
df_scaled = StandardScaler().fit_transform(features)
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled)

# %%
df['cluster'] = cluster_labels
df['component1'] = df_pca[:, 0]
df['component2'] = df_pca[:, 1]
df
# Out:
#     midterm  final  attendance  attitude  homework  cluster  component1  \
# 0        90     94          10         8         8        0   -1.597334
# 1        85     90          10         9         8        0   -1.629745
# 2        98     97          10         9        10        0   -2.692360
# 3        75     70           8         8         9        1   -0.612487
# 4        70     65           8         7         7        1    0.463126
# 5        82     90           8         7         7        0   -0.348063
# 6        95     91           7         5         8        0   -0.283066
# 7        90     97           9         9         9        0   -1.983346
# 8        64     70           7         8         9        1   -0.154728
# 9        59     45           4         5         6        3    2.806838
# 10       60     70           9         9         9        1   -0.744484
# 11       31     56           4         7         7        2    2.387769
# 12       80     85           9        10         9        0   -1.731479
# 13       70     75          10        10        10        1   -1.834993
# 14       89     91          10        10        10        0   -2.595154
# 15       87     61           7         9         8        1   -0.356985
# 16       89     87           9         7         7        0   -0.653977
# 17       94     91           9         9        10        0   -2.250259
# 18       65     31           4         9         7        3    1.764082
# 19       36     45           4         5         6        2    3.296503
# 20       89     96           8         8         9        0   -1.488484
# 21       75     70           7         7         7        1    0.469106
# 22       56     64           6         6         5        1    2.088576
# 23       51     56           6         8         9        3    0.656809
# 24       67     72           8         8         7        1    0.143623
# 25       23     34           8         7         8        2    1.837703
# 26       21     14           2         5         8        4    4.121825
# 27       87     64           9        10         9        1   -1.413711
# 28       45     72           8         7         7        1    0.839772
# 29       34     45           8         2         7        2    2.812991
# 30       78     89          10         7         9        0   -1.318067
#
#     component2
# 0    -0.930687
# 1    -0.471866
# 2     0.106330
# 3     0.452322
# 4    -0.586487
# 5    -1.312913
# 6    -1.575013
# 7    -0.151721
# 8     0.703369
# 9    -0.701316
# 10    0.890599
# 11    0.538224
# 12    0.557104
# 13    1.305414
# 14    0.669253
# 15    0.383872
# 16   -1.438062
# 17    0.382255
# 18    1.160762
# 19   -0.353374
# 20   -0.326156
# 21   -0.686464
# 22   -1.407046
# 23    1.289812
# 24   -0.397674
# 25    1.263905
# 26    1.645918
# 27    0.908917
# 28   -0.360858
# 29   -1.085959
# 30   -0.472457

# %%
df['meanshift_label'] = cluster_labels
centers = meanshift.cluster_centers_
unique_labels = np.unique(cluster_labels)
markers = ['o', 'd', '^', 's', '*']

# %%
for label in unique_labels:
    label_cluster = df[df['meanshift_label'] == label]
    center = centers[label]
    plt.scatter(x=label_cluster['component1'], y=label_cluster['component2'], edgecolor='k', marker=markers[label])
    plt.legend(['cluster 0', 'cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'])
plt.show()

# %% [markdown]
# ## LDA

# %%
df = pd.read_csv(r'D:\git_space\data\grade.csv')
df
# Out:
#            name  midterm  final  attendance  attitude  homework
# 0       Ronaldo       90     94          10         8         8
# 1           Son       85     90          10         9         8
# 2         Messi       98     97          10         9        10
# 3        Dybala       75     70           8         8         9
# 4     Griezmann       70     65           8         7         7
# 5       Benzema       82     90           8         7         7
# 6        Neymar       95     91           7         5         8
# 7        Mbappe       90     97           9         9         9
# 8        Sancho       64     70           7         8         9
# 9         Pogba       59     45           4         5         6
# 10  Ibrahimovic       60     70           9         9         9
# 11         Ozil       31     56           4         7         7
# 12       Werner       80     85           9        10         9
# 13        Kroos       70     75          10        10        10
# 14      Kimmich       89     91          10        10        10
# 15      De Jong       87     61           7         9         8
# 16         Mane       89     87           9         7         7
# 17  Lewandowski       94     91           9         9        10
# 18         Park       65     31           4         9         7
# 19         Alli       36     45           4         5         6
# 20    De Bruyne       89     96           8         8         9
# 21      Mertens       75     70           7         7         7
# 22      Harzard       56     64           6         6         5
# 23        Kante       51     56           6         8         9
# 24      Insigne       67     72           8         8         7
# 25       Lukaku       23     34           8         7         8
# 26      Eriksen       21     14           2         5         8
# 27        Silva       87     64           9        10         9
# 28       Suarez       45     72           8         7         7
# 29      Lingard       34     45           8         2         7
# 30        Ramos       78     89          10         7         9

# %%
# 모든 평가 지표의 만점은 66점이므로 100점이 만점이 되도록 정규화
df['grade'] = (df['midterm']*0.3 + df['final']*0.3 + df['attendance']*0.1 + df['attitude']*0.1 + df['homework']*0.2) * (100 / 66)
df
# Out:
#            name  midterm  final  attendance  attitude  homework      grade
# 0       Ronaldo       90     94          10         8         8  88.787879
# 1           Son       85     90          10         9         8  84.848485
# 2         Messi       98     97          10         9        10  94.545455
# 3        Dybala       75     70           8         8         9  71.060606
# 4     Griezmann       70     65           8         7         7  65.757576
# 5       Benzema       82     90           8         7         7  82.575758
# 6        Neymar       95     91           7         5         8  88.787879
# 7        Mbappe       90     97           9         9         9  90.454545
# 8        Sancho       64     70           7         8         9  65.909091
# 9         Pogba       59     45           4         5         6  50.454545
# 10  Ibrahimovic       60     70           9         9         9  64.545455
# 11         Ozil       31     56           4         7         7  43.333333
# 12       Werner       80     85           9        10         9  80.606061
# 13        Kroos       70     75          10        10        10  71.969697
# 14      Kimmich       89     91          10        10        10  87.878788
# 15      De Jong       87     61           7         9         8  72.121212
# 16         Mane       89     87           9         7         7  84.545455
# 17  Lewandowski       94     91           9         9        10  89.848485
# 18         Park       65     31           4         9         7  47.727273
# 19         Alli       36     45           4         5         6  40.000000
# 20    De Bruyne       89     96           8         8         9  89.242424
# 21      Mertens       75     70           7         7         7  70.151515
# 22      Harzard       56     64           6         6         5  57.878788
# 23        Kante       51     56           6         8         9  53.484848
# 24      Insigne       67     72           8         8         7  67.727273
# 25       Lukaku       23     34           8         7         8  30.606061
# 26      Eriksen       21     14           2         5         8  19.393939
# 27        Silva       87     64           9        10         9  74.242424
# 28       Suarez       45     72           8         7         7  57.575758
# 29      Lingard       34     45           8         2         7  39.545455
# 30        Ramos       78     89          10         7         9  81.212121

# %%
# LDA 는 int으로 target을 받아와야 한다
df['grade'] = df['grade'].astype(int)

# %%
df.drop('name', axis=1, inplace=True)

# %%
features = df.drop('grade', axis=1, inplace=False)
target = df['grade']

# %%
df = pd.DataFrame(data=features, columns=['midterm','final','attendance','attitude','homework'])

# %%
df_scaled = StandardScaler().fit_transform(features) # data 정규화
lda = LinearDiscriminantAnalysis(n_components=2)
lda.fit(df_scaled, target)
df_lda = lda.transform(df_scaled)

# %%
meanshift = MeanShift(bandwidth=18) # bandwidth를 18로 설정해보니 cluster가 다섯 개 형성된다
cluster_labels = meanshift.fit_predict(features)
print(np.unique(cluster_labels))
# Out:
# [0 1 2 3 4]

# %%
df['cluster'] = cluster_labels
df['component1'] = df_lda[:, 0]
df['component2'] = df_lda[:, 1]
df
# Out:
#     midterm  final  attendance  attitude  homework  cluster  component1  \
# 0        90     94          10         8         8        0   99.413679
# 1        85     90          10         9         8        0   79.889114
# 2        98     97          10         9        10        0  123.492325
# 3        75     70           8         8         9        1   12.617906
# 4        70     65           8         7         7        1  -10.048579
# 5        82     90           8         7         7        0   72.094100
# 6        95     91           7         5         8        0  100.796044
# 7        90     97           9         9         9        0  106.026052
# 8        64     70           7         8         9        1  -10.312281
# 9        59     45           4         5         6        3  -81.839232
# 10       60     70           9         9         9        1  -17.041606
# 11       31     56           4         7         7        2 -112.551067
# 12       80     85           9        10         9        0   57.877206
# 13       70     75          10        10        10        1   15.874492
# 14       89     91          10        10        10        0   91.267541
# 15       87     61           7         9         8        1   14.438416
# 16       89     87           9         7         7        0   80.006067
# 17       94     91           9         9        10        0  100.766511
# 18       65     31           4         9         7        3 -102.299833
# 19       36     45           4         5         6        2 -128.208479
# 20       89     96           8         8         9        0  101.110695
# 21       75     70           7         7         7        1   10.868106
# 22       56     64           6         6         5        1  -43.094730
# 23       51     56           6         8         9        3  -69.726593
# 24       67     72           8         8         7        1   -0.043024
# 25       23     34           8         7         8        2 -176.076913
# 26       21     14           2         5         8        4 -230.646010
# 27       87     64           9        10         9        1   23.311561
# 28       45     72           8         7         7        1  -44.223926
# 29       34     45           8         2         7        2 -128.125104
# 30       78     89          10         7         9        0   64.387563
#
#     component2
# 0    -1.593559
# 1    -1.147530
# 2     1.714791
# 3     2.346220
# 4    -0.002727
# 5    -3.607479
# 6    -1.318513
# 7    -0.784972
# 8     0.457181
# 9     0.642075
# 10    0.220727
# 11   -4.681895
# 12    0.618016
# 13    2.322935
# 14    1.934072
# 15    5.656375
# 16   -1.719663
# 17    2.365062
# 18    7.499923
# 19   -3.255283
# 20   -1.145157
# 21   -0.308192
# 22   -4.829003
# 23    1.386608
# 24   -1.698586
# 25    0.143496
# 26    3.382255
# 27    6.540218
# 28   -5.817669
# 29   -3.548295
# 30   -1.771433

# %%
df['meanshift_label'] = cluster_labels
centers = meanshift.cluster_centers_
unique_labels = np.unique(cluster_labels)
markers = ['o', 'd', '*', '^', 's']

# %%
for label in unique_labels:
    label_cluster = df[df['meanshift_label'] == label]
    center = centers[label]
    plt.scatter(x=label_cluster['component1'], y=label_cluster['component2'], edgecolor='k', marker=markers[label])
    plt.legend(['cluster 0', 'cluster 1', 'cluster 2', 'cluster 3', 'cluster 4'])
plt.show()
